# %%
import pandas as pd
import seaborn as sns
import numpy as ny
import matplotlib as ml

# %%
df1 = pd.read_csv("/home/pisop/Téléchargements/sales_predictions.csv")

# %%
print(df1)
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# 2935844           1.0
# 2935845           1.0
# 2935846           1.0
# 2935847           1.0
# 2935848           1.0
#
# [2935849 rows x 6 columns]

# %%
print(df1.columns.values)
# Out:
# ['date' 'date_block_num' 'shop_id' 'item_id' 'item_price' 'item_cnt_day']

# %%
sns.relplot(x="date",y="item_price",data = df1)

# %%
df2 = df1.sample(n=50)

# %%
sns.relplot(x="date",y="item_price", data = df2)

# %%
df2.date = pd.to_datetime(df2.date)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 1913340 to 1324082
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            50 non-null     datetime64[ns]
#  1   date_block_num  50 non-null     int64
#  2   shop_id         50 non-null     int64
#  3   item_id         50 non-null     int64
#  4   item_price      50 non-null     float64
#  5   item_cnt_day    50 non-null     float64
# dtypes: datetime64[ns](1), float64(2), int64(3)
# memory usage: 2.7 KB

# %%
sns.relplot(x="date",y="item_price", data = df2)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-60bba385b997> in <module>
# ----> 1 df1 = df1.Series(np.where(sample.housing.values == 'yes', 1, 0),
#       2           sample.index)
#
# NameError: name 'df1' is not defined
